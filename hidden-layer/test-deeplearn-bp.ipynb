# %%
import numpy as np


def sigmoid(x):
    """
    Calculate sigmoid
    """
    return 1 / (1 + np.exp(-x))


x = np.array([0.5, 0.1, -0.2])
target = 0.6
learnrate = 0.9

weights_input_hidden = np.array([[0.5, -0.6],
                                 [0.1, -0.2],
                                 [0.1, 0.7]])

weights_hidden_output = np.array([0.1, -0.3])

## Forward pass
hidden_layer_input = np.dot(x, weights_input_hidden)
hidden_layer_output = sigmoid(hidden_layer_input)

output_layer_in = np.dot(hidden_layer_output, weights_hidden_output)
print("hidden layer input: {}".format(hidden_layer_output))
print("hidden layer output: {}".format(hidden_layer_output))
print("output layer in: {}".format(output_layer_in))


output = sigmoid(output_layer_in)
print('output : {}'.format(output))
## Backwards pass
## TODO: Calculate output error
error = target - output

# TODO: Calculate error term for output layer
output_error_term = error * output * (1 - output)


# TODO: Calculate error term for hidden layer
hidden_error_term = np.dot(output_error_term, weights_hidden_output) * \
                    hidden_layer_output * (1 - hidden_layer_output)

print("output error term: {}".format(output_error_term))
print("weights hidden output: {}".format(weights_hidden_output))
print("weights input hidden: {}".format(weights_input_hidden))


    
# TODO: Calculate change in weights for hidden layer to output layer
delta_w_h_o = learnrate * output_error_term * hidden_layer_output

# TODO: Calculate change in weights for input layer to hidden layer
delta_w_i_h = learnrate * hidden_error_term * x[:, None]

print('Change in weights for hidden layer to output layer:')
print(delta_w_h_o)
print('Change in weights for input layer to hidden layer:')
print(delta_w_i_h)

weights_input_hidden += delta_w_i_h
weights_hidden_output += delta_w_h_o

print("weights hidden output: {}".format(weights_hidden_output))
print("weights input hidden: {}".format(weights_input_hidden))
# Out:
# hidden layer input: [0.55971365 0.38698582]
# hidden layer output: [0.55971365 0.38698582]
# output layer in: -0.06012438223148006
# output : 0.48497343084992534
# output error term: 0.028730669543515018
# weights hidden output: [ 0.1 -0.3]
# weights input hidden: [[ 0.5 -0.6]
#  [ 0.1 -0.2]
#  [ 0.1  0.7]]
# Change in weights for hidden layer to output layer:
# [0.01447285 0.01000653]
# Change in weights for input layer to hidden layer:
# [[ 3.18609984e-04 -9.20121311e-04]
#  [ 6.37219968e-05 -1.84024262e-04]
#  [-1.27443994e-04  3.68048524e-04]]
# weights hidden output: [ 0.11447285 -0.28999347]
# weights input hidden: [[ 0.50031861 -0.60092012]
#  [ 0.10006372 -0.20018402]
#  [ 0.09987256  0.70036805]]

# %%
## Forward pass

def train(x,weights_input_hidden,weights_hidden_output):
    hidden_layer_input = np.dot(x, weights_input_hidden)
    hidden_layer_output = sigmoid(hidden_layer_input)
    
    print("hidden layer input: {}".format(hidden_layer_input))
    print("hidden layer output: {}".format(hidden_layer_output))
    print("weights input hidden: {}".format(weights_input_hidden))
    print("weights hidden output: {}".format(weights_hidden_output))

    output_layer_in = np.dot(hidden_layer_output, weights_hidden_output)
    
    print("output layer in: {}".format(output_layer_in))

    output = sigmoid(output_layer_in)
    
    print('output : {}'.format(output))
    ## Backwards pass
    ## TODO: Calculate output error
    error = target - output

    # TODO: Calculate error term for output layer
    output_error_term = error * output * (1 - output)

    print("output error term: {}".format(output_error_term))
    print("weights hidden output: {}".format(weights_hidden_output))
    print("hidden layer output: {}".format(hidden_layer_output))

    # TODO: Calculate error term for hidden layer
    hidden_error_term = np.dot(output_error_term, weights_hidden_output) * \
                        hidden_layer_output * (1 - hidden_layer_output)

    # TODO: Calculate change in weights for hidden layer to output layer
    delta_w_h_o = learnrate * output_error_term * hidden_layer_output

    # TODO: Calculate change in weights for input layer to hidden layer
    delta_w_i_h = learnrate * hidden_error_term * x[:, None]

    print('Change in weights for hidden layer to output layer:')
    print(delta_w_h_o)
    print('Change in weights for input layer to hidden layer:')
    print(delta_w_i_h)

    weights_input_hidden += delta_w_i_h
    weights_hidden_output += delta_w_h_o
    
    return weights_input_hidden, weights_hidden_output

# %%
epoch = 1000

print("before loop")
print("w i h {}\n w h o {}".format(weights_input_hidden,weights_hidden_output))

for t in range(epoch):
    print("inside loop")
    weights_input_hidden,weights_hidden_output = train(x,weights_input_hidden,weights_hidden_output)
# Out:
# before loop
# w i h [[ 0.54027606 -0.61363167]
#  [ 0.10805521 -0.20272633]
#  [ 0.08388958  0.70545267]]
#  w h o [0.61840752 0.05571286]
# inside loop
# hidden layer input: [ 0.26416564 -0.468179  ]
# hidden layer output: [0.56566002 0.38504734]
# weights input hidden: [[ 0.54027606 -0.61363167]
#  [ 0.10805521 -0.20272633]
#  [ 0.08388958  0.70545267]]
# weights hidden output: [0.61840752 0.05571286]
# output layer in: 0.3712605007813796
# output : 0.591763524711178
# output error term: 0.0019897632157811736
# weights hidden output: [0.61840752 0.05571286]
# hidden layer output: [0.56566002 0.38504734]
# Change in weights for hidden layer to output layer:
# [0.00101298 0.00068954]
# Change in weights for input layer to hidden layer:
# [[ 1.36042300e-04  1.18120482e-05]
#  [ 2.72084600e-05  2.36240963e-06]
#  [-5.44169200e-05 -4.72481927e-06]]
# inside loop
# hidden layer input: [ 0.26424726 -0.46817191]
# hidden layer output: [0.56568007 0.38504902]
# ...
